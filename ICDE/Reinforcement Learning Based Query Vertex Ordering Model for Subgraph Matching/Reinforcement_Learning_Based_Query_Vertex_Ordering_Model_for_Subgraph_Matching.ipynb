# %% [markdown]
# **RL-QVO**

# %% [markdown]
# This is the first subgraph matching algorithm using machine learning. (And also my first reading paper about subgraph matching).
#
# A good separation of subgraph matching algorithm is that we could divide this task into three parts. **1. Candidate set generation, 2. Matching order generation, 3. Enumeration procedure.** And as far as I know, most of the subgraph matching paper follows this procedure.
#
# Subgraph matching has been proved to be a **NP-hard** problem, so what we could only do is to **reduce the search space** of the matching procedure.
#
# First, for each nodes in the query graph, we could find the **candidate set** in the graph data, so we don't have to try to match each node in the graph data with each node in the query graph(usually, graph data contains a large number of nodes).
#
# Then, to make the search space even more less, we should find a **relatively optimal path** of the query graph to search in the graph data.
#
# Finally, we should use some proper algoithm to **search the path before** in the graph data to get the matched subgraph in it.
#
# As we could see from the procedure, the first step and third step need both **accuracy**(we could not miss a possible candidate or a possible subgraph) and **speed**. In this case, at least for now, in my opinion, we could only use machine learning technique in the **second step** like the author did.
#
# I mainly focus on the machine learning part of this paper. The other part is from an algorithm called "Hybrid". Long story short, they use the Candidate set generation from "GraphQL" and use Enumeration procedure from "QuickSI". Besides, they use "RI" as the baseline of the Matching order generation part.
#
# They changed RI part to the machine learning part. First, they use GCN to learn the embedding of the query graph and use softmax to calculate the probability to **select one unselected node as current node in the matching order**. For each step t(generate embedding for nodes and get a unselected node), they calculate **two different rewards**, $r_val$ and $r_h$ to measure this step. After getting a complete matching order(using all the nodes in the query graph to form a path), they use **Enumeration procedure** to get subgraph in the graph data. And they use the number of enumeration of RI as the baseline, so using enumeration of RL-QVO to substract that of RI would be a **new reward** item(here the author use log algorithm to make the total rewards not unbalanced). Since they use **policy gradient** reinforcement learning as the RL part, they calculate loss for the GCN model based on the rewards.
#
# I've contacted the author, and he said that in this paper, they only consider same number of nodes in the query graph in a train set to make sure the length of the path and the number of the step of RL the same(I reproduce differently by including different length of nodes). And about the performance of the model, the author didn't answer me clearly. He said, and I quoted "I don't know how I make it work, what I only do is adjusting the parameters". Hence, I'm really confused with this paper. Not to mention the log altorithm of the $r_enum$ he gave me was wrong at first.....But still, this is a good idea to explore in the field of subgraph matching

# %%
# !git clone https://github.com/RapidsAtHKUST/SubgraphMatching.git
# Out:
# Cloning into 'SubgraphMatching'...
# remote: Enumerating objects: 278, done.
# remote: Counting objects: 100% (278/278), done.
# remote: Compressing objects: 100% (270/270), done.
# remote: Total 278 (delta 9), reused 260 (delta 3), pack-reused 0
# Receiving objects: 100% (278/278), 2.51 MiB | 14.86 MiB/s, done.
# Resolving deltas: 100% (9/9), done.

# %%
import torch

def format_pytorch_version(version):
  return version.split('+')[0]

TORCH_version = torch.__version__
TORCH = format_pytorch_version(TORCH_version)

def format_cuda_version(version):
  return 'cu' + version.replace('.', '')

CUDA_version = torch.version.cuda

cpu = 1
if cpu:
  CUDA = "cpu"
else:
  CUDA = format_cuda_version(CUDA_version)

# !pip install torch-scatter     -f https://pytorch-geometric.com/whl/torch-{TORCH}+{CUDA}.html
# !pip install torch-sparse      -f https://pytorch-geometric.com/whl/torch-{TORCH}+{CUDA}.html
# !pip install torch-cluster     -f https://pytorch-geometric.com/whl/torch-{TORCH}+{CUDA}.html
# !pip install torch-spline-conv -f https://pytorch-geometric.com/whl/torch-{TORCH}+{CUDA}.html
# !pip install torch-geometric
# Out:
# Looking in links: https://pytorch-geometric.com/whl/torch-1.10.0+cpu.html
# Requirement already satisfied: torch-scatter in /usr/local/lib/python3.7/dist-packages (2.0.9)
# Looking in links: https://pytorch-geometric.com/whl/torch-1.10.0+cpu.html
# Requirement already satisfied: torch-sparse in /usr/local/lib/python3.7/dist-packages (0.6.13)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torch-sparse) (1.4.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scipy->torch-sparse) (1.21.5)
# Looking in links: https://pytorch-geometric.com/whl/torch-1.10.0+cpu.html
# Requirement already satisfied: torch-cluster in /usr/local/lib/python3.7/dist-packages (1.6.0)
# Looking in links: https://pytorch-geometric.com/whl/torch-1.10.0+cpu.html
# Requirement already satisfied: torch-spline-conv in /usr/local/lib/python3.7/dist-packages (1.2.1)
# Requirement already satisfied: torch-geometric in /usr/local/lib/python3.7/dist-packages (2.0.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.4.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (4.63.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (2.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (2.23.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (3.0.7)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.0.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.21.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.3.5)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->torch-geometric) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->torch-geometric) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (3.0.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric) (1.1.0)

# %%
import numpy as np
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import math
from torch_geometric.nn import GCNConv
from collections import defaultdict
from copy import deepcopy
import random

seed = 123

random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)

# %%
class graph():
  def __init__(self, graphid, node2label, node2degree, edges, edge_index):
    self.graphid = graphid
    self.node2label = node2label
    self.node2degree = node2degree
    self.edges = edges
    self.edge_index = edge_index
    self.candidateset = defaultdict(set)
    self.label2node = defaultdict(set)
    for node in self.node2label:
      self.label2node[self.node2label[node]].add(node)
    self.phi = []
    self.phiparent = {}
    self.embeddings = {}

  def reset(self):
    self.candidateset = defaultdict(set)
    self.phi = []
    self.phiparent = {}
    self.embeddings = {}
    
  def init_embedding(self, alphadegree, alphad, alphal, g):
    self.embeddings[0] = torch.zeros(len(self.node2label), 7)
    for node in self.node2degree:
      self.embeddings[0][node][0] = self.node2degree[node] / alphadegree
      self.embeddings[0][node][1] = self.node2label[node]
      self.embeddings[0][node][2] = node
      for v in g.node2degree:
        if self.node2degree[node] < g.node2degree[v]:
          self.embeddings[0][node][3] += 1
        if self.node2label[node] == g.node2label[v]:
          self.embeddings[0][node][4] += 1
      self.embeddings[0][node][3] /= len(g.node2degree) * alphad
      self.embeddings[0][node][4] /= len(g.node2degree) * alphal

# %%
def get_graph(filepath, filename):
  node2label = {}
  node2degree = {}
  edges = defaultdict(set)
  edge_index = []
  f = open(filepath, "r", encoding="utf-8")

  _, nodenum, edgenum = f.readline().strip().split()
  for i in range(int(nodenum)):
    _, nodeid, nodelabel, nodedegree = f.readline().strip().split()
    node2label[int(nodeid)] = int(nodelabel)
    node2degree[int(nodeid)] = int(nodedegree)  
  for i in range(int(edgenum)):
    _, node1, node2 = f.readline().strip().split()
    edges[int(node1)].add(int(node2))
    edges[int(node2)].add(int(node1))
    edge_index.append([int(node1), int(node2)])
    edge_index.append([int(node2), int(node1)])

  f.close()
  edge_index = torch.tensor(edge_index).t()
  g = graph(filename, node2label, node2degree, edges, edge_index)

  return g

# %%
def graphQL(q, g, level):
  marks = set()
  for qnode in q.node2label:
    label = q.node2label[qnode]
    q.candidateset[qnode] |= g.label2node[label]
    for gnode in q.candidateset[qnode]:
      marks.add((qnode, gnode))
  
  for i in range(level):
    for qnode in q.node2label:
      for gnode in q.candidateset[qnode].copy():
        mark = (qnode, gnode)
        if mark not in marks:
          continue
        
        b = set()
        qneighbors = q.edges[qnode]
        gneighbors = g.edges[gnode]
        for qneighbor in qneighbors:
          for gneighbor in gneighbors:
            if gneighbor in q.candidateset[qneighbor]:
              b.add(qneighbor)
              break
        
        semiperfect = qneighbors - b
        if len(semiperfect) == 0:
          marks.remove(mark)
        else:
          q.candidateset[qnode].remove(gnode)
          for qneighbor in qneighbors:
            for gneighbor in gneighbors:
              if gneighbor in q.candidateset[qneighbor]:
                mark = (qneighbor, gneighbor)
                marks.add(mark)

    if len(marks) == 0:
      break

# %%
def RI(q):
  maxdegree = 0
  maxnode = 0
  visited = set()
  for node in q.node2degree:
    if maxdegree < q.node2degree[node]:
      maxdegree = q.node2degree[node]
      maxnode = node
  visited.add(maxnode)
  q.phi.append(maxnode)
  q.phiparent[maxnode] = -1
  while len(visited) != len(q.node2degree):
    m = len(q.phi)
    um = -1
    urank = (-1, -1, -1)
    for node in q.node2degree:
      if node in visited:
        continue
      v1 = visited & q.edges[node]
      v2 = set()
      for vis in visited:
        for vode in q.node2degree:
          if node == vode or vode in visited:
            continue
          if vode in q.edges[vis] and vode in q.edges[node]:
            v2.add(vis)
            break
      v3 = set()
      for vode in q.node2degree:
        flag = True
        if node == vode or vode in visited:
          continue            
        for vis in visited:
          if vode in q.edges[vis]:
            flag = False
            break
        if flag:
          v3.add(vode)
      rank = (len(v1), len(v2), len(v3))
      if urank <= rank:
        um = node
        urank = rank
    for parent in q.phi:
      if parent in q.edges[um]:
        q.phiparent[um] = parent
        break
    q.phi.append(um)
    visited.add(um)

# %%
def QuikSI(q, g, m, i, totalresult): # not equal to the original code
  global count
  count += 1
  if i == len(q.phi) + 1:
    totalresult.append(m.copy())
    return 
  result = {}
  u = -1
  for node in q.phi:
    if node not in m:
      u = node
      break

  lc = set()

  if i == 1:
    vs = g.label2node[q.node2label[u]]
    for v in vs:
      if g.node2degree[v] >= q.node2degree[u]:
        lc.add(v)
  else:
    for v in g.edges[m[q.phiparent[u]]]:
      if q.node2label[u] == g.node2label[v] and g.node2degree[v] >= q.node2degree[u]:
        flag = True
        for node in q.phi:
          if node == u:
            break
          if node == q.phiparent[u]:
            continue
          #if m[node] not in g.edges[v]:
          if v == m[node] or (m[node] not in g.edges[v] and (node in q.edges[u] or u in q.edges[node])):
            flag = False
            break
        if flag:
          lc.add(v)

  for node in lc:
    if node not in set(m.values()):
      m[u] = node
      QuikSI(q, g, m, i + 1, totalresult)
      m.pop(u)

# %%
import os
qs = []
qdir = "SubgraphMatching/test/query_graph"
for f in os.listdir(qdir):
  filepath = os.path.join(qdir, f)
  qs.append(get_graph(filepath, f))

gs = []
gdir = "SubgraphMatching/test/data_graph"
for f in os.listdir(gdir):
  filepath = os.path.join(gdir, f)
  gs.append(get_graph(filepath, f))

print(len(qs))
print(len(gs))

f = open("SubgraphMatching/test/expected_output.res", "r", encoding="utf-8")
lines = f.readlines()
f.close()

expects = {}
for line in lines:
  name, times = line.strip().split(":")
  expects[name + ".graph"] = int(times)
print(len(expects))
# Out:
# 200
# 1
# 200

# %%
queries = {}
basecount = {}
g = gs[0]
#for g in gs:
for q in qs:
  q.reset()
  graphQL(q, g, 10)
  RI(q)
  totalresult = []
  count = 0
  QuikSI(q, g, {}, 1, totalresult)
  queries[q.graphid] = len(totalresult)
  basecount[q.graphid] = count
print(basecount)
# Out:
# {'query_dense_16_95.graph': 2408, 'query_dense_16_125.graph': 236, 'query_dense_16_11.graph': 2346, 'query_dense_16_26.graph': 146, 'query_dense_16_142.graph': 211, 'query_dense_16_186.graph': 178, 'query_dense_16_30.graph': 252, 'query_dense_16_179.graph': 1026, 'query_dense_16_74.graph': 157, 'query_dense_16_58.graph': 74, 'query_dense_16_191.graph': 135, 'query_dense_16_113.graph': 136, 'query_dense_16_62.graph': 120, 'query_dense_16_7.graph': 112, 'query_dense_16_51.graph': 212, 'query_dense_16_20.graph': 154, 'query_dense_16_168.graph': 318, 'query_dense_16_13.graph': 406, 'query_dense_16_35.graph': 449, 'query_dense_16_29.graph': 161, 'query_dense_16_195.graph': 61, 'query_dense_16_17.graph': 64, 'query_dense_16_155.graph': 675, 'query_dense_16_147.graph': 2371, 'query_dense_16_149.graph': 1044, 'query_dense_16_187.graph': 145, 'query_dense_16_139.graph': 611, 'query_dense_16_59.graph': 2498, 'query_dense_16_27.graph': 310, 'query_dense_16_122.graph': 286, 'query_dense_16_4.graph': 85, 'query_dense_16_152.graph': 1976, 'query_dense_16_118.graph': 662, 'query_dense_16_184.graph': 388, 'query_dense_16_156.graph': 87, 'query_dense_16_171.graph': 1400, 'query_dense_16_14.graph': 398, 'query_dense_16_85.graph': 86, 'query_dense_16_64.graph': 52, 'query_dense_16_137.graph': 177, 'query_dense_16_158.graph': 111, 'query_dense_16_172.graph': 62, 'query_dense_16_37.graph': 884, 'query_dense_16_67.graph': 856, 'query_dense_16_177.graph': 227, 'query_dense_16_160.graph': 5636, 'query_dense_16_183.graph': 1036, 'query_dense_16_65.graph': 53, 'query_dense_16_114.graph': 151, 'query_dense_16_18.graph': 43, 'query_dense_16_163.graph': 193, 'query_dense_16_66.graph': 1241, 'query_dense_16_46.graph': 133, 'query_dense_16_87.graph': 840, 'query_dense_16_132.graph': 57, 'query_dense_16_84.graph': 85, 'query_dense_16_107.graph': 311, 'query_dense_16_103.graph': 674, 'query_dense_16_180.graph': 420, 'query_dense_16_68.graph': 1268, 'query_dense_16_1.graph': 221, 'query_dense_16_39.graph': 117, 'query_dense_16_82.graph': 316, 'query_dense_16_143.graph': 73, 'query_dense_16_45.graph': 170, 'query_dense_16_52.graph': 888, 'query_dense_16_126.graph': 525, 'query_dense_16_72.graph': 189, 'query_dense_16_36.graph': 162, 'query_dense_16_131.graph': 64, 'query_dense_16_141.graph': 5897, 'query_dense_16_75.graph': 308, 'query_dense_16_6.graph': 491, 'query_dense_16_128.graph': 469, 'query_dense_16_166.graph': 1603, 'query_dense_16_124.graph': 206, 'query_dense_16_94.graph': 167, 'query_dense_16_63.graph': 156, 'query_dense_16_196.graph': 229, 'query_dense_16_97.graph': 280, 'query_dense_16_117.graph': 858, 'query_dense_16_100.graph': 407, 'query_dense_16_150.graph': 338, 'query_dense_16_102.graph': 87, 'query_dense_16_44.graph': 453, 'query_dense_16_199.graph': 65, 'query_dense_16_165.graph': 1352, 'query_dense_16_15.graph': 702, 'query_dense_16_176.graph': 190, 'query_dense_16_129.graph': 336, 'query_dense_16_86.graph': 44, 'query_dense_16_145.graph': 153, 'query_dense_16_33.graph': 126, 'query_dense_16_98.graph': 307, 'query_dense_16_93.graph': 179, 'query_dense_16_148.graph': 131, 'query_dense_16_49.graph': 373, 'query_dense_16_5.graph': 37, 'query_dense_16_178.graph': 29, 'query_dense_16_47.graph': 1065, 'query_dense_16_28.graph': 140, 'query_dense_16_8.graph': 2040, 'query_dense_16_80.graph': 86, 'query_dense_16_197.graph': 297, 'query_dense_16_159.graph': 275, 'query_dense_16_115.graph': 185, 'query_dense_16_194.graph': 889, 'query_dense_16_71.graph': 180, 'query_dense_16_21.graph': 793, 'query_dense_16_140.graph': 130, 'query_dense_16_19.graph': 64, 'query_dense_16_175.graph': 776, 'query_dense_16_99.graph': 855, 'query_dense_16_108.graph': 536, 'query_dense_16_119.graph': 133, 'query_dense_16_170.graph': 255, 'query_dense_16_173.graph': 407, 'query_dense_16_198.graph': 198, 'query_dense_16_96.graph': 219, 'query_dense_16_22.graph': 942, 'query_dense_16_153.graph': 219, 'query_dense_16_123.graph': 111, 'query_dense_16_53.graph': 280, 'query_den ...

# %%
class PolicyNet(nn.Module):
  def __init__(self, dims):
    super(PolicyNet, self).__init__()
    self.gcns = nn.ModuleList([GCNConv(dims[i - 1], dims[i]) for i in range(1, len(dims) - 2)])
    self.mlps = nn.ModuleList([nn.Linear(dims[i - 1], dims[i]) for i in range(len(dims) - 2, len(dims))])

  def forward(self, x, edge_index):
    for gcn in self.gcns:
      x = gcn(x, edge_index)
    x = self.mlps[0](x)
    x = F.relu(x)
    x = self.mlps[1](x)
    return x

# %%
class RL_QVO():
  def __init__(self, policynet, betaval, betah, posvalidreward, negvalidreward):
    self.policynet = policynet
    self.betaval = betaval
    self.betah = betah
    self.posvalidreward = posvalidreward
    self.negvalidreward = negvalidreward

  def train(self, q):
    step = len(q.node2label)

    steprewards = {}
    entropyrewards = {}
    log_probs = {}
    actions = {}
    for t in range(step):
      if t == 0:
        node = np.random.choice(range(step))
        q.phi.append(node)
        q.phiparent[node] = -1
        continue
      
      q.embeddings[t] = deepcopy(q.embeddings[0])
      
      mask = set()
      for node in q.node2label:
        q.embeddings[t][node][5] = step - t + 1
      
      for node in q.phi:
        q.embeddings[t][node][6] = 1
        mask |= q.edges[node]
      
      mask -= set(q.phi)
      mask = list(mask)
      if len(mask) == 1:
        q.phi.append(mask[0])
        for parent in q.phi:
          if parent in q.edges[mask[0]]:
            q.phiparent[mask[0]] = parent
            break
        continue

      x = q.embeddings[t].to(device)
      edge_index = q.edge_index.to(device)
      result = self.policynet(x, edge_index)
      maxindex = result.argmax().item()
      log_prob = F.softmax(result[mask], dim=0)

      if maxindex in mask:
        steprewards[t] = betaval * self.posvalidreward
      else:
        steprewards[t] = betaval * self.negvalidreward

      nplog = log_prob.t().detach().numpy()
      action = np.random.choice(nplog[0].shape[0], p=nplog[0])
      #action = log_prob.argmax().item()
      q.phi.append(mask[action])
      for parent in q.phi:
        if parent in q.edges[mask[action]]:
          q.phiparent[mask[action]] = parent
          break

      entropyreward = 0;
      for i in range(log_prob.shape[0]):
        if log_prob[i] > 0:
          entropyreward += (-log_prob[i]) * math.log(log_prob[i])
      entropyrewards[t] = betah * entropyreward
      log_probs[t] = log_prob
      actions[t] = action

    return steprewards, entropyrewards, log_probs, actions

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
lr = 0.001
dims = [7, 32, 64, 32, 1]
policynet = PolicyNet(dims).to(device)
optimizer = optim.Adam(policynet.parameters(), lr=lr)
gamma = 0.9
betaval = 2
betah = 2
posvalidreward = 2
negvalidreward = -4 # absolute value should be larger than posvalidreward
clip = 0.1
epochs = 50
alphad = 2
alphal = 2
rlqvo = RL_QVO(policynet, betaval, betah, posvalidreward, negvalidreward)

# %%
def train(qs, epochs):
  global count
  maxlen = 0
  for q in qs:
    q.reset()
    graphQL(q, g, 10)
    alphadegree = 0
    for node in q.candidateset:
      alphadegree = max(alphadegree, len(q.candidateset[node]))
    q.init_embedding(alphadegree, alphad, alphal, g)
    maxlen = max(maxlen, len(q.node2label) - 1)

  for epoch in range(epochs):    
    
    rewards = [0] * maxlen
    tmpprob = defaultdict(dict)
    oldprob = {}

    negcount = 0
    for q in qs:
      q.phi = []
      q.phiparent = {}
      steprewards, entropyrewards, log_probs, actions = rlqvo.train(q)
      totalresult = []
      count = 0

      QuikSI(q, g, {}, 1, totalresult)
      renum = count - basecount[q.graphid]
      if renum < 0:
        negcount += 1
      for t in range(maxlen):
        if renum > 0:
          renum = -math.log(renum)
        elif renum < 0:
          renum = math.log(-renum)
        else:
          renum = 0
        if t in steprewards:
          rewards[t] += math.pow(gamma, t + 1) * (renum + steprewards[t] + entropyrewards[t])
          tmpprob[q.graphid][t] = log_probs[t][actions[t]]
        else:
          rewards[t] = renum
          tmpprob[q.graphid][t] = torch.ones(1)

    print(negcount)

    losses = [0] * maxlen
    for q in qs:
      for t in tmpprob[q.graphid]:
        prob = tmpprob[q.graphid][t]
        if oldprob:
          losses[t] += min(prob / oldprob[q.graphid][t] * rewards[t], torch.clamp(prob / oldprob[q.graphid][t], 1.0 - clip, 1.0 + clip) * rewards[t])
        else:
          losses[t] += min(prob * rewards[t], torch.clamp(prob, 1.0 - clip, 1.0 + clip) * rewards[t])
    
    oldprob = tmpprob

    optimizer.zero_grad()
    loss = sum(losses) / len(qs)
    loss.backward()
    optimizer.step()
    print("Epoch: {0}, Loss: {1}， Rewards: {2}".format(epoch, loss.item(), sum(rewards).item() / len(qs)))

count = 0
train(random.sample(qs, 20), 10)
train(qs, 20)
# Out:
# 6
# Epoch: 0, Loss: -209.5333251953125， Rewards: -11.534709930419922
# 5
# Epoch: 1, Loss: -280.9226989746094， Rewards: -15.559794616699218
# 9
# Epoch: 2, Loss: -277.1666259765625， Rewards: -15.161428833007813
# 9
# Epoch: 3, Loss: -304.9398193359375， Rewards: -16.73919219970703
# 8
# Epoch: 4, Loss: -207.1382293701172， Rewards: -11.327440643310547
# 8
# Epoch: 5, Loss: -248.55313110351562， Rewards: -13.622523498535156
# 8
# Epoch: 6, Loss: -314.2757263183594， Rewards: -17.23102264404297
# 10
# Epoch: 7, Loss: -459.470458984375， Rewards: -25.006153869628907
# 11
# Epoch: 8, Loss: -301.82757568359375， Rewards: -16.409774780273438
# 7
# Epoch: 9, Loss: -258.6339111328125， Rewards: -14.02100067138672
# 76
# Epoch: 0, Loss: -680.8646240234375， Rewards: -3.6920266723632813
# 74
# Epoch: 1, Loss: -401.4454650878906， Rewards: -2.1790840148925783
# 80
# Epoch: 2, Loss: -675.1590576171875， Rewards: -3.63631103515625
# 72
# Epoch: 3, Loss: -436.1169128417969， Rewards: -2.344932403564453
# 81
# Epoch: 4, Loss: -507.0707092285156， Rewards: -2.7317205810546876
# 78
# Epoch: 5, Loss: -1020.1724853515625， Rewards: -5.47159912109375
# 82
# Epoch: 6, Loss: -824.350341796875， Rewards: -4.4353329467773435
# 76
# Epoch: 7, Loss: -150.20692443847656， Rewards: -0.8031501770019531
# 83
# Epoch: 8, Loss: -446.20880126953125， Rewards: -2.393363037109375
# 76
# Epoch: 9, Loss: -367.5424499511719， Rewards: -1.959827880859375
# 81
# Epoch: 10, Loss: -908.337158203125， Rewards: -4.859917297363281
# 79
# Epoch: 11, Loss: -591.8369750976562， Rewards: -3.161026611328125
# 71
# Epoch: 12, Loss: -418.3483581542969， Rewards: -2.228823547363281
# 81
# Epoch: 13, Loss: -833.4392700195312， Rewards: -4.408861999511719
# 85
# Epoch: 14, Loss: -641.88720703125， Rewards: -3.3952896118164064
# 80
# Epoch: 15, Loss: -745.5089721679688， Rewards: -3.9366168212890624
# 72
# Epoch: 16, Loss: -1098.982666015625， Rewards: -5.803968505859375
# 96
# Epoch: 17, Loss: -772.9481201171875， Rewards: -4.086206359863281
# 84
# Epoch: 18, Loss: -685.24365234375， Rewards: -3.597445373535156
# 77
# Epoch: 19, Loss: -548.0521850585938， Rewards: -2.89636962890625

# %%
fastercount = 0
fasterfreq = 0
for q in qs:
  q.reset()
  graphQL(q, g, 10)
  alphadegree = 0
  for node in q.candidateset:
    alphadegree = max(alphadegree, len(q.candidateset[node]))
  q.init_embedding(alphadegree, alphad, alphal, g)
  graphQL(q, g, 10)
  steprewards, entropyrewards, log_probs, actions = rlqvo.train(q)
  totalresult = []
  count = 0
  QuikSI(q, g, {}, 1, totalresult)
  if len(totalresult) == queries[q.graphid]:
    if count < basecount[q.graphid]:
      fasterfreq += 1
    fastercount += basecount[q.graphid] - count
    print("Q: {0}, Baseline: {1}, RLQVO: {2}".format(q.graphid, basecount[q.graphid], count))
  else:
    print("Q: {0} is wrong".format(q.graphid))

print("RLQVO total faster percentage: {0}, total faster count: {1}".format(fasterfreq / len(qs), fastercount))
# Out:
# Q: query_dense_16_95.graph, Baseline: 2408, RLQVO: 1524
# Q: query_dense_16_125.graph, Baseline: 236, RLQVO: 190
# Q: query_dense_16_11.graph, Baseline: 2346, RLQVO: 1702
# Q: query_dense_16_26.graph, Baseline: 146, RLQVO: 1664
# Q: query_dense_16_142.graph, Baseline: 211, RLQVO: 487
# Q: query_dense_16_186.graph, Baseline: 178, RLQVO: 81
# Q: query_dense_16_30.graph, Baseline: 252, RLQVO: 190
# Q: query_dense_16_179.graph, Baseline: 1026, RLQVO: 1871
# Q: query_dense_16_74.graph, Baseline: 157, RLQVO: 1302
# Q: query_dense_16_58.graph, Baseline: 74, RLQVO: 35
# Q: query_dense_16_191.graph, Baseline: 135, RLQVO: 42
# Q: query_dense_16_113.graph, Baseline: 136, RLQVO: 154
# Q: query_dense_16_62.graph, Baseline: 120, RLQVO: 114
# Q: query_dense_16_7.graph, Baseline: 112, RLQVO: 66
# Q: query_dense_16_51.graph, Baseline: 212, RLQVO: 2737
# Q: query_dense_16_20.graph, Baseline: 154, RLQVO: 517
# Q: query_dense_16_168.graph, Baseline: 318, RLQVO: 2816
# Q: query_dense_16_13.graph, Baseline: 406, RLQVO: 6292
# Q: query_dense_16_35.graph, Baseline: 449, RLQVO: 290
# Q: query_dense_16_29.graph, Baseline: 161, RLQVO: 532
# Q: query_dense_16_195.graph, Baseline: 61, RLQVO: 51
# Q: query_dense_16_17.graph, Baseline: 64, RLQVO: 1549
# Q: query_dense_16_155.graph, Baseline: 675, RLQVO: 604
# Q: query_dense_16_147.graph, Baseline: 2371, RLQVO: 7440
# Q: query_dense_16_149.graph, Baseline: 1044, RLQVO: 532
# Q: query_dense_16_187.graph, Baseline: 145, RLQVO: 8652
# Q: query_dense_16_139.graph, Baseline: 611, RLQVO: 516
# Q: query_dense_16_59.graph, Baseline: 2498, RLQVO: 2496
# Q: query_dense_16_27.graph, Baseline: 310, RLQVO: 234
# Q: query_dense_16_122.graph, Baseline: 286, RLQVO: 244
# Q: query_dense_16_4.graph, Baseline: 85, RLQVO: 168
# Q: query_dense_16_152.graph, Baseline: 1976, RLQVO: 22952
# Q: query_dense_16_118.graph, Baseline: 662, RLQVO: 1373
# Q: query_dense_16_184.graph, Baseline: 388, RLQVO: 571
# Q: query_dense_16_156.graph, Baseline: 87, RLQVO: 590
# Q: query_dense_16_171.graph, Baseline: 1400, RLQVO: 84
# Q: query_dense_16_14.graph, Baseline: 398, RLQVO: 725
# Q: query_dense_16_85.graph, Baseline: 86, RLQVO: 315
# Q: query_dense_16_64.graph, Baseline: 52, RLQVO: 48
# Q: query_dense_16_137.graph, Baseline: 177, RLQVO: 88
# Q: query_dense_16_158.graph, Baseline: 111, RLQVO: 148
# Q: query_dense_16_172.graph, Baseline: 62, RLQVO: 361
# Q: query_dense_16_37.graph, Baseline: 884, RLQVO: 134
# Q: query_dense_16_67.graph, Baseline: 856, RLQVO: 1767
# Q: query_dense_16_177.graph, Baseline: 227, RLQVO: 2396
# Q: query_dense_16_160.graph, Baseline: 5636, RLQVO: 6344
# Q: query_dense_16_183.graph, Baseline: 1036, RLQVO: 1098
# Q: query_dense_16_65.graph, Baseline: 53, RLQVO: 115
# Q: query_dense_16_114.graph, Baseline: 151, RLQVO: 267
# Q: query_dense_16_18.graph, Baseline: 43, RLQVO: 99
# Q: query_dense_16_163.graph, Baseline: 193, RLQVO: 1676
# Q: query_dense_16_66.graph, Baseline: 1241, RLQVO: 1404
# Q: query_dense_16_46.graph, Baseline: 133, RLQVO: 198
# Q: query_dense_16_87.graph, Baseline: 840, RLQVO: 1049
# Q: query_dense_16_132.graph, Baseline: 57, RLQVO: 92
# Q: query_dense_16_84.graph, Baseline: 85, RLQVO: 153
# Q: query_dense_16_107.graph, Baseline: 311, RLQVO: 216
# Q: query_dense_16_103.graph, Baseline: 674, RLQVO: 1478
# Q: query_dense_16_180.graph, Baseline: 420, RLQVO: 24
# Q: query_dense_16_68.graph, Baseline: 1268, RLQVO: 1404
# Q: query_dense_16_1.graph, Baseline: 221, RLQVO: 151
# Q: query_dense_16_39.graph, Baseline: 117, RLQVO: 133
# Q: query_dense_16_82.graph, Baseline: 316, RLQVO: 203
# Q: query_dense_16_143.graph, Baseline: 73, RLQVO: 42
# Q: query_dense_16_45.graph, Baseline: 170, RLQVO: 240
# Q: query_dense_16_52.graph, Baseline: 888, RLQVO: 760
# Q: query_dense_16_126.graph, Baseline: 525, RLQVO: 948
# Q: query_dense_16_72.graph, Baseline: 189, RLQVO: 125
# Q: query_dense_16_36.graph, Baseline: 162, RLQVO: 113
# Q: query_dense_16_131.graph, Baseline: 64, RLQVO: 113
# Q: query_dense_16_141.graph, Baseline: 5897, RLQVO: 903
# Q: query_dense_16_75.graph, Baseline: 308, RLQVO: 183
# Q: query_dense_16_6.graph, Baseline: 491, RLQVO: 3657
# Q: query_dense_16_128.graph, Baseline: 469, RLQVO: 10874
# Q: query_dense_16_166.graph, Baseline: 1603, RLQVO: 932
# Q: query_dense_16_124.graph, Baseline: 206, RLQVO: 119
# Q: query_dense_16_94.graph, Baseline: 167, RLQVO: 165
# Q: query_dense_16_63.graph, Baseline: 156, RLQVO: 310
# Q: query_dense_16_196.graph, Baseline: 229, RLQVO: 89
# Q: query_dense_16_97.graph, Baseline: 280, RLQVO: 714
# Q: query_dense_16_117.graph, Baseline: 858, RLQVO: 288
# Q: query_dense_16_100.graph, Baseline: 407, RLQVO: 129
# Q: query_dense_16_150.graph, Baseline: 338, RLQVO: 346
# Q: query_dense_16_102.graph, Baseline: 87, RLQVO: 68
# Q: query_dense_16_44.graph, Baseline: 453, RLQVO: 708
# Q: query_dense_16_199.graph, Baseline: 65, RLQVO: 30
# Q: query_dense_16_165.graph, Baseline: 1352, RLQVO: 1322
# Q: query_dense_16_15.graph, Baseline: 702, RLQVO: 136
# Q: query_dense_16_176.graph, Baseline: 190, RLQVO: 768
# Q: query_dense_16_129.graph, Baseline: 336, RLQVO: 412
# Q: query_dense_16_86.graph, Baseline: 44, RLQVO: 100
# Q: query_dense_16_145.graph, Baseline: 153, RLQVO: 22
# Q: query_dense_16_33.graph, Baseline: 126, RLQVO: 195
# Q: query_dense_16_98.graph, Baseline: 307, RLQVO: 380
# Q: query_dense_16_93.graph, Baseline: 179, RLQVO: 127
# Q: query_dense_16_148.graph, Baseline: 131, RLQVO: 542
# Q: query_dense_16_49.graph, Baseline: 373, RLQVO: 334
# Q: query_dense_16_5.graph, Baseline: 37, RLQVO: 41
# Q: query_dense_16_178.graph, Baseline: 29, RLQVO: 74
# Q: query_dense_16_47.graph, Baseline: 1065, RLQVO: 346
# Q: query_dense_16_28.graph, Baseline: 140, RLQVO: 272
# Q: query_dense_16_8.graph, Baseline: 2040, RLQVO: 47245
# Q: query_dense_16_80.graph, Baseline: 86, RLQVO: 148
# Q: query_dense_16_197.graph, Baseline: 297, RLQVO: 156
# Q: query_dense_16_159.graph, Baseline: 275, RLQVO: 143
# Q: query_dense_16_115.graph, Baseline: 185, RLQVO: 119
# Q: query_dense_16_194.graph, Baseline: 889, RLQVO: 49
# Q: query_dense_16_71.graph, Baseline: 180, RLQVO: 948
# Q: query_dense_16_21.graph, Baseline: 793, RLQVO: 418
# Q: query_dense_16_140.graph, Baseline: 130, RLQVO: 135
# Q: query_dense_16_19.graph, Baseline: 64, RLQVO: 262
# Q: query_dense_16_175.graph, Baseline: 776, RLQVO: 459
# Q: query_dense_16_99.graph, Baseline: 855, RLQVO: 1532
# Q: query_dense_16_108.graph, Baseline: 536, RLQVO: 1628
# Q: query_dense_16_119.graph, Baseline: 133, RLQVO: 118
# Q: query_dense_16_170.graph, Baseline: 255, RLQVO: 270
# Q: query_dense_16_173.graph, Baseline: 407, RLQVO: 226
# Q: query_dense_16_198.graph, Baseline: 198, RLQVO: 982
# Q: query_dense_16_96.graph, Baseline: 219, RLQVO: 699
# Q: query_dense_16_22.graph, Baseline: 942, RLQVO: 603
# Q: query_dense_16_153.graph, Baseline: 219, RLQVO: 748
# Q: query_dense_16_123.graph, Baseline: 111, RLQVO: 104
# Q: query_dense_16_53.graph, Baseline: 280, RLQVO: 579
# Q: query_dense_16_88.graph, Baseline: 509, RLQVO: 245
# Q: query_dense_16_188.graph, Baseline: 408, RLQVO: 282
# Q: query_dense_16_55.graph, Baseline: 133, RLQVO: 102
# Q: query_dense_16_50.graph, Baseline: 353, RLQVO: 219
# Q: query_dense_16_174.graph, Baseline: 482, RLQVO: 604
# Q: query_dense_16_83.graph, Baseline: 270, RLQVO: 91
# Q: query_dense_16_48.graph, Baseline: 61, RLQVO: 128
# Q: query_dense_16_135.graph, Baseline: 128, RLQVO: 74
# Q: query_dense_16_42.graph, Baseline: 259, RLQVO: 595
# Q: query_dense_16_38.graph, Baseline: 21670, RLQVO: 2113
# Q: query_dense_16_12.graph, Baseline: 320, RLQVO: 1272
# Q: query_dense_16_24.graph, Baseline: 582, RLQVO: 548
# Q: query_dense_16_73.graph, Baseline: 258, RLQVO: 314
# Q: query_dense_16_110.graph, Baseline: 57, RLQVO: 126
# Q: query_dense_16_167.graph, Baseline: 412, RLQVO: 784
# Q: query_dense_16_164.graph, Baseline: 680, RLQVO: 766
# Q: query_dense_16_193.graph, Baseline: 192, RLQVO: 568
# Q: query_dense_16_31.graph, Baseline: 243, RLQVO: 783
# Q: query_dense_16_189.graph, Baseline: 306, RLQVO: 369
# Q: query_dense_16_23.graph, Baseline: 124, RLQVO: 156
# Q: query_dense_16_192.graph, Baseline: 56, RLQVO: 216
# Q: query_dense_16_76.graph, Baseline: 1481, RLQVO: 4363
# Q: query_dense_16_79.graph, Baseline: 166, RLQVO: 805
# Q: query_dense_16_134.graph, Baseline: 368, RLQVO: 678
# Q: query_dense_16_69.graph, Baseline: 1019, RLQVO: 183
# Q: query_dense_16_41.graph, Baseline: 1310, RLQVO: 1053
# Q: query_dense_16_32.graph, Baseline: 85, RLQVO: 112
# Q: query_dense_16_78.graph, Baseline: 89, RLQVO: 485
# Q: query_dense_16_89.graph, Baseline: 839, RLQVO: 284
# Q: query_dense_16_105.graph, Baseline: 48, RLQVO: 110
# Q: query_dense_16_146.graph, Baseline: 175, RLQVO: 206
# Q: query_dense_16_109.graph, Baseline: 719, RLQVO: 370
# Q: query_dense_16_136.graph, Baseline: 52, RLQVO: 30
# Q: query_dense_16_157.graph, Baseline: 335, RLQVO: 292
# Q: query_dense_16_161.graph, Baseline: 344, RLQVO: 140
# Q: query_dense_16_25.graph, Baseline: 104, RLQVO: 699
# Q: query_dense_16_151.graph, Baseline: 500, RLQVO: 4432
# Q: query_dense_16_104.graph, Baseline: 139, RLQVO: 90
# Q: query_dense_16_91.graph, Baseline: 548, RLQVO: 424
# Q: query_dense_16_3.graph, Baseline: 39, RLQVO: 171
# Q: query_dense_16_121.graph, Baseline: 1257, RLQVO: 167
# Q: query_dense_16_154.graph, Baseline: 1084, RLQVO: 93
# Q: query_dense_16_190.graph, Baseline: 178, RLQVO: 679
# Q: query_dense_16_2.graph, Baseline: 767, RLQVO: 377
# Q: query_dense_16_43.graph, Baseline: 27, RLQVO: 36
# Q: query_dense_16_16.graph, Baseline: 465, RLQVO: 568
# Q: query_dense_16_162.graph, Baseline: 347, RLQVO: 241
# Q: query_dense_16_133.graph, Baseline: 180, RLQVO: 1105
# Q: query_dense_16_138.graph, Baseline: 136, RLQVO: 167
# Q: query_dense_16_111.graph, Baseline: 432, RLQVO: 1293
# Q: query_dense_16_54.graph, Baseline: 613, RLQVO: 282
# Q: query_dense_16_10.graph, Baseline: 445, RLQVO: 799
# Q: query_dense_16_9.graph, Baseline: 556, RLQVO: 190
# Q: query_dense_16_185.graph, Baseline: 139, RLQVO: 90
# Q: query_dense_16_34.graph, Baseline: 160, RLQVO: 56
# Q: query_dense_16_182.graph, Baseline: 198, RLQVO: 188
# Q: query_dense_16_60.graph, Baseline: 576, RLQVO: 844
# Q: query_dense_16_56.graph, Baseline: 214, RLQVO: 205
# Q: query_dense_16_57.graph, Baseline: 182, RLQVO: 115
# Q: query_dense_16_112.graph, Baseline: 316, RLQVO: 107
# Q: query_dense_16_127.graph, Baseline: 301, RLQVO: 2666
# Q: query_dense_16_61.graph, Baseline: 1391, RLQVO: 1982
# Q: query_dense_16_106.graph, Baseline: 359, RLQVO: 132
# Q: query_dense_16_169.graph, Baseline: 579, RLQVO: 519
# Q: query_dense_16_92.graph, Baseline: 75, RLQVO: 424
# Q: query_dense_16_90.graph, Baseline: 2822, RLQVO: 2847
# Q: query_dense_16_130.graph, Baseline: 236, RLQVO: 164
# Q: query_dense_16_70.graph, Baseline: 172, RLQVO: 1777
# Q: query_dense_16_81.graph, Baseline: 418, RLQVO: 181
# Q: query_dense_16_40.graph, Baseline: 245, RLQVO: 557
# Q: query_dense_16_144.graph, Baseline: 175, RLQVO: 1193
# Q: query_dense_16_116.graph, Baseline: 45, RLQVO: 96
# Q: query_dense_16_120.graph, Baseline: 257, RLQVO: 1460
# Q: query_dense_16_101.graph, Baseline: 221, RLQVO: 197
# Q: query_dense_16_77.graph, Baseline: 994, RLQVO: 242
# Q: query_dense_16_200.graph, Baseline: 211, RLQVO: 266
# Q: query_dense_16_181.graph, Baseline: 603, RLQVO: 280
# RLQVO total faster percentage: 0.455, total faster count: -105207

# %%
def bfs(q):
  visited = set()
  queue = []
  nodes = [i for i in range(len(q.node2label))]
  node = random.choice(nodes)
  queue.append(node)
  visited.add(node)
  q.phiparent[node] = -1
  q.phi.append(node)
  while queue:
    node = queue[0]
    if node not in visited:
      q.phi.append(node)
    queue.pop(0)
    visited.add(node)
    for neighbor in q.edges[node]:
      if neighbor not in visited:
        q.phiparent[neighbor] = node
        queue.append(neighbor)


fastercount = 0
fasterfreq = 0
for q in qs:
  q.reset()
  graphQL(q, g, 10)
  
  bfs(q)

  totalresult = []
  count = 0
  QuikSI(q, g, {}, 1, totalresult)
  if len(totalresult) == queries[q.graphid]:
    if count < basecount[q.graphid]:
      fasterfreq += 1
    fastercount += basecount[q.graphid] - count
    print("Q: {0}, Baseline: {1}, Random: {2}".format(q.graphid, basecount[q.graphid], count))
  else:
    print("Q: {0} is wrong".format(q.graphid))

print("Random total faster percentage: {0}, total faster count: {1}".format(fasterfreq / len(qs), fastercount))
# Out:
# Q: query_dense_16_95.graph, Baseline: 2408, Random: 5638
# Q: query_dense_16_125.graph, Baseline: 236, Random: 244
# Q: query_dense_16_11.graph, Baseline: 2346, Random: 1083
# Q: query_dense_16_26.graph, Baseline: 146, Random: 218
# Q: query_dense_16_142.graph, Baseline: 211, Random: 89
# Q: query_dense_16_186.graph, Baseline: 178, Random: 56
# Q: query_dense_16_30.graph, Baseline: 252, Random: 395
# Q: query_dense_16_179.graph, Baseline: 1026, Random: 2482
# Q: query_dense_16_74.graph, Baseline: 157, Random: 298
# Q: query_dense_16_58.graph, Baseline: 74, Random: 49
# Q: query_dense_16_191.graph, Baseline: 135, Random: 104
# Q: query_dense_16_113.graph, Baseline: 136, Random: 216
# Q: query_dense_16_62.graph, Baseline: 120, Random: 131
# Q: query_dense_16_7.graph, Baseline: 112, Random: 1021
# Q: query_dense_16_51.graph, Baseline: 212, Random: 510
# Q: query_dense_16_20.graph, Baseline: 154, Random: 71
# Q: query_dense_16_168.graph, Baseline: 318, Random: 1052
# Q: query_dense_16_13.graph, Baseline: 406, Random: 1401
# Q: query_dense_16_35.graph, Baseline: 449, Random: 208
# Q: query_dense_16_29.graph, Baseline: 161, Random: 1852
# Q: query_dense_16_195.graph, Baseline: 61, Random: 287
# Q: query_dense_16_17.graph, Baseline: 64, Random: 1094
# Q: query_dense_16_155.graph, Baseline: 675, Random: 881
# Q: query_dense_16_147.graph, Baseline: 2371, Random: 9402
# Q: query_dense_16_149.graph, Baseline: 1044, Random: 527
# Q: query_dense_16_187.graph, Baseline: 145, Random: 27
# Q: query_dense_16_139.graph, Baseline: 611, Random: 1049
# Q: query_dense_16_59.graph, Baseline: 2498, Random: 5278
# Q: query_dense_16_27.graph, Baseline: 310, Random: 5466
# Q: query_dense_16_122.graph, Baseline: 286, Random: 2830
# Q: query_dense_16_4.graph, Baseline: 85, Random: 849
# Q: query_dense_16_152.graph, Baseline: 1976, Random: 1476
# Q: query_dense_16_118.graph, Baseline: 662, Random: 6520
# Q: query_dense_16_184.graph, Baseline: 388, Random: 1711
# Q: query_dense_16_156.graph, Baseline: 87, Random: 1055
# Q: query_dense_16_171.graph, Baseline: 1400, Random: 661
# Q: query_dense_16_14.graph, Baseline: 398, Random: 368
# Q: query_dense_16_85.graph, Baseline: 86, Random: 219
# Q: query_dense_16_64.graph, Baseline: 52, Random: 765
# Q: query_dense_16_137.graph, Baseline: 177, Random: 637
# Q: query_dense_16_158.graph, Baseline: 111, Random: 408
# Q: query_dense_16_172.graph, Baseline: 62, Random: 433
# Q: query_dense_16_37.graph, Baseline: 884, Random: 2352
# Q: query_dense_16_67.graph, Baseline: 856, Random: 389
# Q: query_dense_16_177.graph, Baseline: 227, Random: 663
# Q: query_dense_16_160.graph, Baseline: 5636, Random: 9198
# Q: query_dense_16_183.graph, Baseline: 1036, Random: 517
# Q: query_dense_16_65.graph, Baseline: 53, Random: 155
# Q: query_dense_16_114.graph, Baseline: 151, Random: 310
# Q: query_dense_16_18.graph, Baseline: 43, Random: 181
# Q: query_dense_16_163.graph, Baseline: 193, Random: 857
# Q: query_dense_16_66.graph, Baseline: 1241, Random: 537
# Q: query_dense_16_46.graph, Baseline: 133, Random: 357
# Q: query_dense_16_87.graph, Baseline: 840, Random: 7832
# Q: query_dense_16_132.graph, Baseline: 57, Random: 93
# Q: query_dense_16_84.graph, Baseline: 85, Random: 32
# Q: query_dense_16_107.graph, Baseline: 311, Random: 1340
# Q: query_dense_16_103.graph, Baseline: 674, Random: 664
# Q: query_dense_16_180.graph, Baseline: 420, Random: 444
# Q: query_dense_16_68.graph, Baseline: 1268, Random: 2240
# Q: query_dense_16_1.graph, Baseline: 221, Random: 114
# Q: query_dense_16_39.graph, Baseline: 117, Random: 24249
# Q: query_dense_16_82.graph, Baseline: 316, Random: 653
# Q: query_dense_16_143.graph, Baseline: 73, Random: 47
# Q: query_dense_16_45.graph, Baseline: 170, Random: 465
# Q: query_dense_16_52.graph, Baseline: 888, Random: 581
# Q: query_dense_16_126.graph, Baseline: 525, Random: 1076
# Q: query_dense_16_72.graph, Baseline: 189, Random: 589
# Q: query_dense_16_36.graph, Baseline: 162, Random: 94
# Q: query_dense_16_131.graph, Baseline: 64, Random: 457
# Q: query_dense_16_141.graph, Baseline: 5897, Random: 8088
# Q: query_dense_16_75.graph, Baseline: 308, Random: 1372
# Q: query_dense_16_6.graph, Baseline: 491, Random: 4704
# Q: query_dense_16_128.graph, Baseline: 469, Random: 59138
# Q: query_dense_16_166.graph, Baseline: 1603, Random: 1612
# Q: query_dense_16_124.graph, Baseline: 206, Random: 262
# Q: query_dense_16_94.graph, Baseline: 167, Random: 252
# Q: query_dense_16_63.graph, Baseline: 156, Random: 847
# Q: query_dense_16_196.graph, Baseline: 229, Random: 839
# Q: query_dense_16_97.graph, Baseline: 280, Random: 867
# Q: query_dense_16_117.graph, Baseline: 858, Random: 261
# Q: query_dense_16_100.graph, Baseline: 407, Random: 1798
# Q: query_dense_16_150.graph, Baseline: 338, Random: 149
# Q: query_dense_16_102.graph, Baseline: 87, Random: 188
# Q: query_dense_16_44.graph, Baseline: 453, Random: 311
# Q: query_dense_16_199.graph, Baseline: 65, Random: 237
# Q: query_dense_16_165.graph, Baseline: 1352, Random: 951
# Q: query_dense_16_15.graph, Baseline: 702, Random: 3026
# Q: query_dense_16_176.graph, Baseline: 190, Random: 481
# Q: query_dense_16_129.graph, Baseline: 336, Random: 292
# Q: query_dense_16_86.graph, Baseline: 44, Random: 572
# Q: query_dense_16_145.graph, Baseline: 153, Random: 31
# Q: query_dense_16_33.graph, Baseline: 126, Random: 302
# Q: query_dense_16_98.graph, Baseline: 307, Random: 284
# Q: query_dense_16_93.graph, Baseline: 179, Random: 151
# Q: query_dense_16_148.graph, Baseline: 131, Random: 483
# Q: query_dense_16_49.graph, Baseline: 373, Random: 528
# Q: query_dense_16_5.graph, Baseline: 37, Random: 30
# Q: query_dense_16_178.graph, Baseline: 29, Random: 70
# Q: query_dense_16_47.graph, Baseline: 1065, Random: 1281
# Q: query_dense_16_28.graph, Baseline: 140, Random: 565
# Q: query_dense_16_8.graph, Baseline: 2040, Random: 28072
# Q: query_dense_16_80.graph, Baseline: 86, Random: 280
# Q: query_dense_16_197.graph, Baseline: 297, Random: 719
# Q: query_dense_16_159.graph, Baseline: 275, Random: 427
# Q: query_dense_16_115.graph, Baseline: 185, Random: 158
# Q: query_dense_16_194.graph, Baseline: 889, Random: 228
# Q: query_dense_16_71.graph, Baseline: 180, Random: 236
# Q: query_dense_16_21.graph, Baseline: 793, Random: 43
# Q: query_dense_16_140.graph, Baseline: 130, Random: 2032
# Q: query_dense_16_19.graph, Baseline: 64, Random: 745
# Q: query_dense_16_175.graph, Baseline: 776, Random: 578
# Q: query_dense_16_99.graph, Baseline: 855, Random: 3031
# Q: query_dense_16_108.graph, Baseline: 536, Random: 361
# Q: query_dense_16_119.graph, Baseline: 133, Random: 197
# Q: query_dense_16_170.graph, Baseline: 255, Random: 136
# Q: query_dense_16_173.graph, Baseline: 407, Random: 898
# Q: query_dense_16_198.graph, Baseline: 198, Random: 200
# Q: query_dense_16_96.graph, Baseline: 219, Random: 308
# Q: query_dense_16_22.graph, Baseline: 942, Random: 1115
# Q: query_dense_16_153.graph, Baseline: 219, Random: 248
# Q: query_dense_16_123.graph, Baseline: 111, Random: 154
# Q: query_dense_16_53.graph, Baseline: 280, Random: 549
# Q: query_dense_16_88.graph, Baseline: 509, Random: 499
# Q: query_dense_16_188.graph, Baseline: 408, Random: 342
# Q: query_dense_16_55.graph, Baseline: 133, Random: 66
# Q: query_dense_16_50.graph, Baseline: 353, Random: 732
# Q: query_dense_16_174.graph, Baseline: 482, Random: 4105
# Q: query_dense_16_83.graph, Baseline: 270, Random: 141
# Q: query_dense_16_48.graph, Baseline: 61, Random: 103
# Q: query_dense_16_135.graph, Baseline: 128, Random: 319
# Q: query_dense_16_42.graph, Baseline: 259, Random: 536
# Q: query_dense_16_38.graph, Baseline: 21670, Random: 12381
# Q: query_dense_16_12.graph, Baseline: 320, Random: 1283
# Q: query_dense_16_24.graph, Baseline: 582, Random: 1822
# Q: query_dense_16_73.graph, Baseline: 258, Random: 825
# Q: query_dense_16_110.graph, Baseline: 57, Random: 199
# Q: query_dense_16_167.graph, Baseline: 412, Random: 1164
# Q: query_dense_16_164.graph, Baseline: 680, Random: 4113
# Q: query_dense_16_193.graph, Baseline: 192, Random: 168
# Q: query_dense_16_31.graph, Baseline: 243, Random: 1416
# Q: query_dense_16_189.graph, Baseline: 306, Random: 43
# Q: query_dense_16_23.graph, Baseline: 124, Random: 201
# Q: query_dense_16_192.graph, Baseline: 56, Random: 324
# Q: query_dense_16_76.graph, Baseline: 1481, Random: 2154
# Q: query_dense_16_79.graph, Baseline: 166, Random: 261
# Q: query_dense_16_134.graph, Baseline: 368, Random: 99
# Q: query_dense_16_69.graph, Baseline: 1019, Random: 82
# Q: query_dense_16_41.graph, Baseline: 1310, Random: 3118
# Q: query_dense_16_32.graph, Baseline: 85, Random: 1058
# Q: query_dense_16_78.graph, Baseline: 89, Random: 286
# Q: query_dense_16_89.graph, Baseline: 839, Random: 102
# Q: query_dense_16_105.graph, Baseline: 48, Random: 367
# Q: query_dense_16_146.graph, Baseline: 175, Random: 161
# Q: query_dense_16_109.graph, Baseline: 719, Random: 2683
# Q: query_dense_16_136.graph, Baseline: 52, Random: 97
# Q: query_dense_16_157.graph, Baseline: 335, Random: 126
# Q: query_dense_16_161.graph, Baseline: 344, Random: 1471
# Q: query_dense_16_25.graph, Baseline: 104, Random: 2042
# Q: query_dense_16_151.graph, Baseline: 500, Random: 836
# Q: query_dense_16_104.graph, Baseline: 139, Random: 1101
# Q: query_dense_16_91.graph, Baseline: 548, Random: 631
# Q: query_dense_16_3.graph, Baseline: 39, Random: 647
# Q: query_dense_16_121.graph, Baseline: 1257, Random: 1931
# Q: query_dense_16_154.graph, Baseline: 1084, Random: 1233
# Q: query_dense_16_190.graph, Baseline: 178, Random: 407
# Q: query_dense_16_2.graph, Baseline: 767, Random: 852
# Q: query_dense_16_43.graph, Baseline: 27, Random: 1760
# Q: query_dense_16_16.graph, Baseline: 465, Random: 1863
# Q: query_dense_16_162.graph, Baseline: 347, Random: 406
# Q: query_dense_16_133.graph, Baseline: 180, Random: 691
# Q: query_dense_16_138.graph, Baseline: 136, Random: 192
# Q: query_dense_16_111.graph, Baseline: 432, Random: 91
# Q: query_dense_16_54.graph, Baseline: 613, Random: 1703
# Q: query_dense_16_10.graph, Baseline: 445, Random: 712
# Q: query_dense_16_9.graph, Baseline: 556, Random: 2274
# Q: query_dense_16_185.graph, Baseline: 139, Random: 1436
# Q: query_dense_16_34.graph, Baseline: 160, Random: 41
# Q: query_dense_16_182.graph, Baseline: 198, Random: 317
# Q: query_dense_16_60.graph, Baseline: 576, Random: 1640
# Q: query_dense_16_56.graph, Baseline: 214, Random: 201
# Q: query_dense_16_57.graph, Baseline: 182, Random: 243
# Q: query_dense_16_112.graph, Baseline: 316, Random: 392
# Q: query_dense_16_127.graph, Baseline: 301, Random: 418
# Q: query_dense_16_61.graph, Baseline: 1391, Random: 841
# Q: query_dense_16_106.graph, Baseline: 359, Random: 682
# Q: query_dense_16_169.graph, Baseline: 579, Random: 253
# Q: query_dense_16_92.graph, Baseline: 75, Random: 737
# Q: query_dense_16_90.graph, Baseline: 2822, Random: 2883
# Q: query_dense_16_130.graph, Baseline: 236, Random: 555
# Q: query_dense_16_70.graph, Baseline: 172, Random: 700
# Q: query_dense_16_81.graph, Baseline: 418, Random: 360
# Q: query_dense_16_40.graph, Baseline: 245, Random: 1109
# Q: query_dense_16_144.graph, Baseline: 175, Random: 107
# Q: query_dense_16_116.graph, Baseline: 45, Random: 155
# Q: query_dense_16_120.graph, Baseline: 257, Random: 1605
# Q: query_dense_16_101.graph, Baseline: 221, Random: 234
# Q: query_dense_16_77.graph, Baseline: 994, Random: 1542
# Q: query_dense_16_200.graph, Baseline: 211, Random: 290
# Q: query_dense_16_181.graph, Baseline: 603, Random: 180
# Random total faster percentage: 0.28, total faster count: -205468
